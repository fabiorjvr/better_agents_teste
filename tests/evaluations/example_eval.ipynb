# %% [markdown]
# # Avaliação: Receitas Vegetarianas
#
# Este notebook define métricas básicas de sucesso, latência e custo para o agente de receitas.

# %%
# TODO: carregar cenários e calcular métricas
# Exemplo de estrutura:
# - precision/recall para critérios
# - latência média por chamada
# - custo por execução (se disponível)
